# %% [markdown]
# # K-means & Hierarchical Clustering

# %%
# 1. Load your dataset.

# %%
import pandas as pd

data=pd.read_csv(r"C:\Users\LAOUEDJ Said\Desktop\AI\Checkpoint\Checkpoint9_K-means & Hierarchical Clustering\CC GENERAL.csv", sep = ',')


data=data.drop("CUST_ID", axis=1) 
data_del=data.dropna(axis=0,how='any',thresh=None,inplace=False)
data_del.info()
data_del.isnull().sum()

#we are gonne use only this data in order to show the clusters
X = data_del.iloc[:, :].values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8636 entries, 0 to 8949
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   BALANCE                           8636 non-null   float64
#  1   BALANCE_FREQUENCY                 8636 non-null   float64
#  2   PURCHASES                         8636 non-null   float64
#  3   ONEOFF_PURCHASES                  8636 non-null   float64
#  4   INSTALLMENTS_PURCHASES            8636 non-null   float64
#  5   CASH_ADVANCE                      8636 non-null   float64
#  6   PURCHASES_FREQUENCY               8636 non-null   float64
#  7   ONEOFF_PURCHASES_FREQUENCY        8636 non-null   float64
#  8   PURCHASES_INSTALLMENTS_FREQUENCY  8636 non-null   float64
#  9   CASH_ADVANCE_FREQUENCY            8636 non-null   float64
#  10  CASH_ADVANCE_TRX                  8636 non-null   int64
# ...

# %%
# 2. Use hierarchical clustering to identify the inherent groupings within your data.

# %%
model = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward')
model.fit(X)
#The labels_ property returns an array of integers where the values correspond to the distinct categories.
labels = model.labels_

# %%
# 3. Plot the clusters

# %%
plt.scatter(X[labels==0, 2], X[labels==0, 3], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 2], X[labels==1, 3], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 2], X[labels==2, 3], s=50, marker='o', color='green')
plt.scatter(X[labels==3, 2], X[labels==3, 3], s=50, marker='o', color='purple')
plt.scatter(X[labels==4, 2], X[labels==4, 3], s=50, marker='o', color='orange')
plt.title('Agglomerative Clustering')
plt.xlabel('PURCHASES')
plt.ylabel('ONEOFF_PURCHASES')
plt.legend('01234')
plt.show()

# %% [markdown]
# 4. Plot the dendrogram.

# %%
 
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(data_del, method='ward'))

# %%
 # Use K-means clustering.

# %%
from sklearn.cluster import KMeans

from yellowbrick.cluster import KElbowVisualizer

# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(2,12))

visualizer.fit(X)        # Fit the data to the visualizer
visualizer        # Finalize and render the figure
# Out:
# KElbowVisualizer(ax=<AxesSubplot:>, estimator=KMeans(n_clusters=11), k=(2, 12))

# %%
model = KMeans(n_clusters=6)
model.fit(X)
#The labels_ property returns an array of integers where the values correspond to the distinct categories.
labels = model.labels_

# %%
# Plot the clusters.

# %%
plt.scatter(X[labels==0, 2], X[labels==0, 3], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 2], X[labels==1, 3], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 2], X[labels==2, 3], s=50, marker='o', color='green')
plt.scatter(X[labels==3, 2], X[labels==3, 3], s=50, marker='o', color='purple')
plt.scatter(X[labels==4, 2], X[labels==4, 3], s=50, marker='o', color='orange')
plt.scatter(X[labels==5, 2], X[labels==5, 3], s=50, marker='o', color='pink')
plt.title('Kmeans Clustering')
plt.xlabel('PURCHASES')
plt.ylabel('ONEOFF_PURCHASES')
plt.legend('012345')
plt.show()
